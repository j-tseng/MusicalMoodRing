# %%
# Pipeline:
#   - Initialize based on quick quiz about what songs participants listen to while working
#   - Signals recorded while participants work and listen to music 
#   - Types of focus playlists: instrumental vs lyrical, valence, arousal
#   - Threshold focus, if certain playlist is not working then adjust to new playlist
#   - At first, ask participants what kind of working playlist they want
#   - ^ record mental state, attempt to predict without asking eventually
#   - Interface with Spotify

# MVP:
#   - Record my brain activity while working for 10 songs
#   - Rank them based on alpha/beta content (threshold)
#   - Update model of user song preferences based on type of song
#   - Update Spotify playlists
